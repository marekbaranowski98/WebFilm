# %% [markdown]
# # Przygotowanie danych

# %% [markdown]
# ## Importy

# %%
import os
import re
import ast
import requests
import datetime

import pandas as pd
import numpy as np

from tqdm import tqdm
from uuid import uuid4
from flag import flag
from sqlalchemy import create_engine

# %% [markdown]
# ## Stałe

# %%
MKDIR_DATA = 'data/'
MKDIR_IMAGE = 'image/'

MKDIR_MOVIES = os.path.join(MKDIR_IMAGE, 'movies')
MKDIR_COLLECTIONS = os.path.join(MKDIR_IMAGE, 'collections')
MKDIR_PEOPLE = os.path.join(MKDIR_IMAGE, 'people')

MOVIES_CSV = os.path.join(MKDIR_DATA, 'movies_metadata.csv')
KEYWORDS_CSV = os.path.join(MKDIR_DATA, 'keywords.csv')
CREDITS_CSV = os.path.join(MKDIR_DATA, 'credits.csv')
RATINGS_CSV = os.path.join(MKDIR_DATA,'ratings.csv')
LINKS_CSV = os.path.join(MKDIR_DATA, 'links.csv')


API_KEY = 'API KEY'
URL_API = 'https://api.themoviedb.org/3/'

URL_IMAGE = 'http://image.tmdb.org/t/p/original/'

MAX_FOLDER_IMAGE_GB = 0.1

DB_HOST = '127.0.0.1'
DB_NAME = 'webfilm'
DB_USER = 'webfilm'
DB_PASS = 'nhy6&UJM'

# %% [markdown]
# ## Utworzenie folderów

# %%
list_folders = [
    MKDIR_DATA,
    MKDIR_IMAGE,
    MKDIR_MOVIES,
    MKDIR_COLLECTIONS,
    MKDIR_PEOPLE,
]
for x in list_folders:
    if not os.path.exists(x):
        os.makedirs(x)

# %% [markdown]
# ## Ustawienia środowiska

# %%
PANDAS_MAX_ROW = 10

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', PANDAS_MAX_ROW)

# %% [markdown]
# ## Pobranie danych

# %%
# !kaggle datasets download -p $MKDIR_DATA --unzip rounakbanik/the-movies-dataset

file = open(MOVIES_CSV, 'r')
wiersz = 1
usunac_nowy_wiersz = [19763, 29572, 35671]
tekst = ''
for line in tqdm(file):
    if wiersz in usunac_nowy_wiersz:
        line = line.strip()

    wiersz = wiersz + 1
    tekst += line
file.close()

file = open(MOVIES_CSV, 'w')
file.write(tekst)
file.close()
# Out:
# Downloading the-movies-dataset.zip to data
#  99%|███████████████████████████████████████▌| 225M/228M [00:08<00:00, 30.4MB/s]
# 100%|████████████████████████████████████████| 228M/228M [00:08<00:00, 27.5MB/s]
# 45573it [00:00, 111015.61it/s]

# %% [markdown]
# ## Wczytanie danych
# Wczytanie i podzielenie danych

# %% [markdown]
# ### Movies

# %%
movies = pd.read_csv(MOVIES_CSV, keep_default_na=False)
movies = movies.drop_duplicates('id').sort_values('id')
movies = movies.rename(columns={
    'belongs_to_collection': 'collection_id',
    'original_language': 'original_language_id',
    'status': 'status_id',
})
movies = movies.drop('poster_path', axis=1)
movies = movies.drop('imdb_id', axis=1)
movies = movies.drop('popularity', axis=1)
movies = movies.drop('vote_average', axis=1)
movies = movies.drop('vote_count', axis=1)

movies.head()
# Out:
#        adult                                      collection_id    budget  \
# 4342   False                                                            0
# 12947  False                                                            0
# 17     False                                                      4000000
# 474    False                                                            0
# 256    False  {'id': 10, 'name': 'Star Wars Collection', 'po...  11000000
#
#                                                   genres  \
# 4342   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 12947  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 17     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 474    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 256    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                                 homepage  id  \
# 4342                                                       2
# 12947                                                      3
# 17                                                         5
# 474                                                        6
# 256    http://www.starwars.com/films/star-wars-episod...  11
#
#       original_language_id        original_title  \
# 4342                    fi                 Ariel
# 12947                   fi  Varjoja paratiisissa
# 17                      en            Four Rooms
# 474                     en        Judgment Night
# 256                     en             Star Wars
#
#                                                 overview  \
# 4342   Taisto Kasurinen is a Finnish coal miner whose...
# 12947  An episode in the life of Nikander, a garbage ...
# 17     It's Ted the Bellhop's first night on the job....
# 474    While racing to a boxing match, Frank, Mike, J...
# 256    Princess Leia is captured and held hostage by ...
#
#                                     production_companies  \
# 4342   [{'name': 'Villealfa Filmproduction Oy', 'id':...
# 12947  [{'name': 'Villealfa Filmproduction Oy', 'id':...
# 17     [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 474    [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 256    [{'name': 'Lucasfilm', 'id': 1}, {'name': 'Twe...
#
#                                     production_countries release_date  \
# 4342           [{'iso_3166_1': 'FI', 'name': 'Finland'}]   1988-10-21
# 12947          [{'iso_3166_1': 'FI', 'name': 'Finland'}]   1986-10-16
# 17     [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-09
# 474    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...   1993-10-15
# 256    [{'iso_3166_1': 'US', 'name': 'United States o...   1977-05-25
#
#          revenue runtime                                   spoken_languages  \
# 4342           0    69.0  [{'iso_639_1': 'fi', 'name': 'suomi'}, {'iso_6...
# 12947          0    76.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 17       4300000    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 474     12136938   110.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 256    775398007   121.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status_id                                            tagline  \
# 4342   Released
# 12947  Released
# 17     Released  Twelve outrageous guests. Four scandalous requ...
# 474    Released     Don't move. Don't whisper. Don't even breathe.
# 256    Released       A long time ago in a galaxy far, far away...
#
#                      title  video
# 4342                 Ariel  False
# 12947  Shadows in Paradise  False
# 17              Four Rooms  False
# 474         Judgment Night  False
# 256              Star Wars  False

# %% [markdown]
# ### Collection

# %%
collection = []
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if data['collection_id'] != '':
        tmp = ast.literal_eval(data['collection_id'])
        collection.append({
            'id': tmp['id'],
            'name': tmp['name'],
        })
        movies.at[label, 'collection_id'] = tmp['id']
    else:
        movies.at[label, 'collection_id'] = None
# Out:
# 100%|███████████████████████████████████| 45433/45433 [00:09<00:00, 4567.53it/s]

# %%
collection = pd.DataFrame(collection).sort_values('id').drop_duplicates('name')
collection.head()
# Out:
#      id                                       name
# 0    10                       Star Wars Collection
# 17   84                   Indiana Jones Collection
# 28  119           The Lord of the Rings Collection
# 25  131                    Three Colors Collection
# 37  151  Star Trek: The Original Series Collection

# %% [markdown]
# ### Genres

# %%
genres = []
movies_genres = []
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if data['genres'] != '':
        tmp = ast.literal_eval(data['genres'])
        for x in tmp:
            movies_genres.append({
                'genre_id': x['id'],
                'movie_id': data['id'],
            })
            genres.append(x)
movies = movies.drop('genres', axis=1)
# Out:
# 100%|███████████████████████████████████| 45433/45433 [00:18<00:00, 2512.31it/s]

# %%
genres = pd.DataFrame(genres).sort_values('id').drop_duplicates('id')
genres.head()
# Out:
#        id       name
# 6784   12  Adventure
# 65263  14    Fantasy
# 37860  16  Animation
# 29936  18      Drama
# 19538  27     Horror

# %%
movies_genres = pd.DataFrame(movies_genres).drop_duplicates()
movies_genres.head()
# Out:
#    genre_id  movie_id
# 0        18         2
# 1        80         2
# 2        18         3
# 3        35         3
# 4        80         5

# %% [markdown]
# ### Production companies

# %%
def check_name_in_list(list_dict, search_name):
    for x in list_dict:
        if x['name'] == search_name:
            return True, x
    return False, -1

# %%
production_companies = []
movies_companies = []
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if data['production_companies'] != '':
        tmp = ast.literal_eval(data['production_companies'])
        for x in tmp:
            found, position = check_name_in_list(production_companies, x['name'])
            if found:
                movies_companies.append({
                    'movie_id': data['id'],
                    'company_id': position['id'],
                })                
            else:                    
                movies_companies.append({
                    'movie_id': data['id'],
                    'company_id': x['id'],
                })
                production_companies.append(x)
movies = movies.drop('production_companies', axis=1)
# Out:
# 100%|████████████████████████████████████| 45433/45433 [03:54<00:00, 193.65it/s]

# %%
company = pd.DataFrame(production_companies).sort_values('id').drop_duplicates('id')
company.head()
# Out:
#                        name  id
# 7                 Lucasfilm   1
# 51     Walt Disney Pictures   2
# 9   Pixar Animation Studios   3
# 10       Paramount Pictures   4
# 45        Columbia Pictures   5

# %%
movies_companies = pd.DataFrame(movies_companies).drop_duplicates()
movies_companies.head()
# Out:
#    movie_id  company_id
# 0         2        2303
# 1         2        2396
# 2         3        2303
# 3         5          14
# 4         5          59

# %% [markdown]
# ### Production countries

# %%
production_countries = []
movies_prod_countries = []
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if data['production_countries'] != '':
        tmp = ast.literal_eval(data['production_countries'])
        for x in tmp:
            movies_prod_countries.append({
                'movie_id': data['id'],
                'country_id': x['iso_3166_1'],
            })
            production_countries.append(x)
movies = movies.drop('production_countries', axis=1)
# Out:
# 100%|███████████████████████████████████| 45433/45433 [00:09<00:00, 4959.66it/s]

# %%
countries = pd.DataFrame(production_countries).sort_values('iso_3166_1').drop_duplicates('iso_3166_1')
countries.at[countries['iso_3166_1'] == 'CD', 'name'] = 'Congo, the Democratic Republic of the'
countries.head()
# Out:
#       iso_3166_1                  name
# 36535         AE  United Arab Emirates
# 43061         AF           Afghanistan
# 45308         AL               Albania
# 40191         AM               Armenia
# 38993         AN  Netherlands Antilles

# %%
movies_countries = pd.DataFrame(movies_prod_countries).drop_duplicates()
movies_countries.head()
# Out:
#    movie_id country_id
# 0         2         FI
# 1         3         FI
# 2         5         US
# 3         6         JP
# 4         6         US

# %% [markdown]
# ### Spoken languages

# %%
spoken_languages = []
movies_spoken_languages = []
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if data['spoken_languages'] != '':
        tmp = ast.literal_eval(data['spoken_languages'])
        for x in tmp:
            movies_spoken_languages.append({
                'movie_id': data['id'],
                'language_id': x['iso_639_1'],
            })
            spoken_languages.append(x)
movies = movies.drop('spoken_languages', axis=1)
# Out:
# 100%|███████████████████████████████████| 45433/45433 [00:07<00:00, 6302.45it/s]

# %%
languages = pd.DataFrame(spoken_languages).sort_values('iso_639_1').drop_duplicates('iso_639_1')
languages.head()
# Out:
#       iso_639_1       name
# 47548        ab
# 1274         af  Afrikaans
# 36875        am
# 8625         ar    العربية
# 10013        as

# %%
spoken_languages = pd.DataFrame(movies_spoken_languages).drop_duplicates()
spoken_languages.head()
# Out:
#    movie_id language_id
# 0         2          fi
# 1         2          de
# 2         3          en
# 3         3          fi
# 4         3          sv

# %% [markdown]
# ### Keywords

# %%
keywords = pd.read_csv(KEYWORDS_CSV, keep_default_na=False)
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
keywords_list = []
movies_keywords = []
for label, data  in tqdm(keywords.iterrows(), total=keywords.shape[0]):
    if data['keywords'] != '':
        tmp = ast.literal_eval(data['keywords'])
        for x in tmp:
            movies_keywords.append({
                'movie_id': data['id'],
                'keyword_id': x['id'],
            })
            keywords_list.append({
                'id': x['id'],
                'name': x['name'],
            })
# Out:
# 100%|███████████████████████████████████| 46419/46419 [00:13<00:00, 3428.58it/s]

# %%
keywords = pd.DataFrame(keywords_list).sort_values('id').drop_duplicates('name')
keywords.head()
# Out:
#        id              name
# 20195  30        individual
# 78924  65           holiday
# 88272  74           germany
# 85300  75        gunslinger
# 17875  83  saving the world

# %%
movies_keywords = pd.DataFrame(movies_keywords).drop_duplicates()
movies_keywords.head()
# Out:
#    movie_id  keyword_id
# 0       862         931
# 1       862        4290
# 2       862        5202
# 3       862        6054
# 4       862        9713

# %% [markdown]
# ### Credits

# %%
credits = pd.read_csv(CREDITS_CSV)
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# #### Cast

# %%
cast = []
person = []
for label, data  in tqdm(credits.iterrows(), total=credits.shape[0]):
    if data['cast'] != '':
        tmp = ast.literal_eval(data['cast'])
        for x in tmp:
            cast.append({
                'movie_id': data['id'],
                'character': x['character'],
                'person_id': x['id'],
                'order': x['order'],
            })
            identity = x.get('name', '').split(' ', 1)
            name = identity[0]
            if len(identity) > 1:
                surname = identity[1]
            else:
                surname = ''
            person.append({
                'id': x['id'],
                'name': name,
                'surname': surname,
                'gender': x['gender'],
            })
# Out:
# 100%|████████████████████████████████████| 45476/45476 [00:51<00:00, 889.12it/s]

# %%
cast = pd.DataFrame(cast).drop_duplicates()
cast.head()
# Out:
#    movie_id                character  person_id  order
# 0       862            Woody (voice)         31      0
# 1       862   Buzz Lightyear (voice)      12898      1
# 2       862  Mr. Potato Head (voice)       7167      2
# 3       862       Slinky Dog (voice)      12899      3
# 4       862              Rex (voice)      12900      4

# %% [markdown]
# #### Crew

# %%
crew = []
for label, data  in tqdm(credits.iterrows(), total=credits.shape[0]):
    if data['cast'] != '':
        tmp = ast.literal_eval(data['crew'])
        for x in tmp:
            crew.append({
                'movie_id': data['id'],
                'department': x['department'],
                'job': x['job'],
                'person_id': x['id'],
            })
            identity = x.get('name', '').split(' ', 1)
            name = identity[0]
            if len(identity) > 1:
                surname = identity[1]
            else:
                surname = ''
            person.append({
                'id': x['id'],
                'name': name,
                'surname': surname,
                'gender': x['gender'],
            })
# Out:
# 100%|███████████████████████████████████| 45476/45476 [00:44<00:00, 1014.30it/s]

# %%
crew = pd.DataFrame(crew).drop_duplicates()
crew.head()
# Out:
#    movie_id department         job  person_id
# 0       862  Directing    Director       7879
# 1       862    Writing  Screenplay      12891
# 2       862    Writing  Screenplay          7
# 3       862    Writing  Screenplay      12892
# 4       862    Writing  Screenplay      12893

# %%
people = pd.DataFrame(person).sort_values('id').drop_duplicates('id')
people.head()
# Out:
#         id      name  surname  gender
# 161631   1    George    Lucas       2
# 195489   2      Mark   Hamill       2
# 340878   3  Harrison     Ford       2
# 20669    4    Carrie   Fisher       1
# 142927   5     Peter  Cushing       2

# %% [markdown]
# ### Links

# %%
links = pd.read_csv(LINKS_CSV, keep_default_na=False, low_memory=True)
links['tmdbId'] = pd.to_numeric(links.tmdbId, downcast='integer')
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# ### Ratings

# %%
def process_rating_chunk(ratings):
    ratings = ratings.merge(links, left_on='movieId', right_on='movieId')
    ratings = ratings.rename(columns={
        'userId': 'user_id',
        'tmdbId': 'movie_id',
        'timestamp': 'date',
    })
    ratings = ratings.sort_values(['date'])
    ratings['date'] = pd.to_datetime(ratings['date'], unit='s')
    
    ratings = ratings.drop('movieId', axis=1)
    ratings = ratings.drop('imdbId', axis=1)
#     ratings['rating'] = ratings.rating.apply(lambda x: x * 2)

    return ratings

# %%
ratings = pd.read_csv(RATINGS_CSV, keep_default_na=False, low_memory=True)

ratings = process_rating_chunk(ratings)
ratings = ratings[ratings['movie_id'].isin(movies['id'])]
ratings = ratings.drop_duplicates(subset=['user_id', 'movie_id', ], keep='last')
ratings

# %%
ratings.astype({'rating': 'int32'}).groupby(['rating']).size()

# %%
ax = ratings.groupby(['rating']).size().plot.bar(title='Rozkład ocen')
ax.set_xlabel('Oceny')
ax.set_ylabel('Liczba ocen w mln')
ax.get_figure().savefig('rozkład ocen.png')

# %%
ratings
# Out:
#           user_id  rating                date  movie_id
# 20925665    38150     8.0 1995-01-09 11:46:44    1600.0
# 12937605    44717     6.0 1995-01-09 11:46:49    8012.0
# 4842674     44717     6.0 1995-01-09 11:46:49     623.0
# 3870682     44717    10.0 1995-01-09 11:46:49     807.0
# 6295319    187396    10.0 1996-01-29 00:00:00    9598.0
# ...           ...     ...                 ...       ...
# 11605097    85434     4.0 2017-08-04 06:38:59   13342.0
# 23907954    85434     6.0 2017-08-04 06:39:06   10140.0
# 19982064    85434     8.0 2017-08-04 06:41:23   19186.0
# 20803205   199634     6.0 2017-08-04 06:53:43    1724.0
# 25912983   179412     7.0 2017-08-04 06:57:50  335791.0
#
# [25981457 rows x 4 columns]

# %% [markdown]
# # Pobranie zdjęć

# %%
gallery = []
photos = []
gallery_id = 1

def download_poster(folderToSave, poster_path) -> (str, int):
    imgUrl = f'{URL_IMAGE}{poster_path}'
    name = str(uuid4())
    try:
        image = f'{folderToSave}/{name}'
        session = requests.Session()
        r = session.get(imgUrl, stream=True, verify=False)
        if r.status_code == 200:
            with open(image, 'wb') as f:
                for chunk in r.iter_content(chunk_size=1024):
                    f.write(chunk)
            return (name, os.path.getsize(image))
        else:
            raise Exception()
    except Exception as e:
        return ('00000000-0000-0000-0000-000000000000', 0)

# %% [markdown]
# ## Movies

# %%
size = 0
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    gallery.append(gallery_id)
    try:
        if size < MAX_FOLDER_IMAGE_GB * 1024**3:
            response = requests.get(f'{URL_API}movie/{data["id"]}?api_key={API_KEY}')
            response = response.json()
            poster_path = response['poster_path']

            image, s = download_poster(MKDIR_MOVIES, poster_path)
            photos.append({
                'url': image,
                'gallery_id': gallery_id,
                'order': 1,
            })
            photos.append({
                'url': '00000000-0000-0000-0000-000000000000',
                'gallery_id': gallery_id,
                'order': 2,
            })
            size = size + s
        else:
            raise Exception()
    except:
        photos.append({
            'url': '00000000-0000-0000-0000-000000000000',
            'gallery_id': gallery_id,
            'order': 1,
        })
        photos.append({
            'url': '00000000-0000-0000-0000-000000000000',
            'gallery_id': gallery_id,
            'order': 2,
        })
    finally:
        gallery_id = gallery_id + 1        
movies['gallery_id'] = gallery
movies
# Out:
# 100%|████████████████████████████████████| 45433/45433 [02:05<00:00, 361.03it/s]
#        adult collection_id    budget  \
# 4342   False          None         0
# 12947  False          None         0
# 17     False          None   4000000
# 474    False          None         0
# 256    False            10  11000000
# ...      ...           ...       ...
# 45075  False          None         0
# 45270  False          None         0
# 21890  False          None         0
# 45395  False          None   1254040
# 20188  False          None         0
#
#                                                 homepage      id  \
# 4342                                                           2
# 12947                                                          3
# 17                                                             5
# 474                                                            6
# 256    http://www.starwars.com/films/star-wars-episod...      11
# ...                                                  ...     ...
# 45075                                                     465044
# 45270                                                     467731
# 21890                                                     468343
# 45395                                    http://lmtr.fi/  468707
# 20188                                                     469172
#
#       original_language_id                    original_title  \
# 4342                    fi                             Ariel
# 12947                   fi              Varjoja paratiisissa
# 17                      en                        Four Rooms
# 474                     en                    Judgment Night
# 256                     en                         Star Wars
# ...                    ...                               ...
# 45075                   en                         Abduction
# 45270                   en       Tragedy in a Temporary Town
# 21890                   fi          Silja - nuorena nukkunut
# 45395                   fi  Lauri Mäntyvaaran tuuheet ripset
# 20188                   pt  Manoel dans l'île des merveilles
#
#                                                 overview release_date  \
# 4342   Taisto Kasurinen is a Finnish coal miner whose...   1988-10-21
# 12947  An episode in the life of Nikander, a garbage ...   1986-10-16
# 17     It's Ted the Bellhop's first night on the job....   1995-12-09
# 474    While racing to a boxing match, Frank, Mike, J...   1993-10-15
# 256    Princess Leia is captured and held hostage by ...   1977-05-25
# ...                                                  ...          ...
# 45075  A horror comedy spoofing conspiracy theory mov...   2017-06-28
# 45270  Fifteen-year-old girl Dotty Fisher is assaulte...   1956-02-19
# 21890  In the 1910s, beautiful young Silja loses both...   1956-01-01
# 45395                                                      2017-07-28
# 20188  Manuel is a young boy who travels from long ag...   1984-08-02
#
#          revenue runtime status_id  \
# 4342           0    69.0  Released
# 12947          0    76.0  Released
# 17       4300000    98.0  Released
# 474     12136938   110.0  Released
# 256    775398007   121.0  Released
# ...          ...     ...       ...
# 45075          0    90.0  Released
# 45270          0    60.0  Released
# 21890          0    87.0  Released
# 45395          0    90.0  Released
# 20188          0   130.0  Released
#
#                                                  tagline  \
# 4342
# 12947
# 17     Twelve outrageous guests. Four scandalous requ...
# 474       Don't move. Don't whisper. Don't even breathe.
# 256         A long time ago in a galaxy far, far away...
# ...                                                  ...
# 45075                                 Horrifically Funny
# 45270
# 21890
# 45395
# 20188
#
#                                   title  video  gallery_id
# 4342                              Ariel  False           1
# 12947               Shadows in Paradise  False           2
# 17                           Four Rooms  False           3
# 474                      Judgment Night  False           4
# 256                           Star Wars  False           5
# ...                                 ...    ...         ...
# 45075                         Abduction  False       45429
# 45270       Tragedy in a Temporary Town  False       45430
# 21890          Silja - nuorena nukkunut  False       45431
# 45395  Thick Lashes of Lauri Mäntyvaara  False       45432
# 20188   Manuel on the Island of Wonders  False       45433
#
# [45433 rows x 16 columns]

# %% [markdown]
# ## Collection

# %%
size = 0
gallery_last = gallery[-1]
for label, data  in tqdm(collection.iterrows(), total=collection.shape[0]):
    gallery.append(gallery_id)
    try:
        if size < MAX_FOLDER_IMAGE_GB * 1024**3:
            response = requests.get(f'{URL_API}collection/{data["id"]}?api_key={API_KEY}')
            if response.status_code == 200:
                response = response.json()
                image, s = download_poster(MKDIR_COLLECTIONS, response['poster_path'])
                photos.append({
                    'url': image,
                    'gallery_id': gallery_id,
                    'order': 1,
                })
                size = size + s
                image, s = download_poster(MKDIR_COLLECTIONS, response['backdrop_path'])
                photos.append({
                    'url': image,
                    'gallery_id': gallery_id,
                    'order': 2,
                })
                size = size + s
            else:
                raise Exception()
        else:
            raise Exception()
    except Exception:
        photos.append({
            'url': '00000000-0000-0000-0000-000000000000',
            'gallery_id': gallery_id,
            'order': 1,
        })
        photos.append({
            'url': '00000000-0000-0000-0000-000000000000',
            'gallery_id': gallery_id,
            'order': 2,
        })
    finally:
        gallery_id = gallery_id + 1
collection['gallery_id'] = gallery[gallery_last:]
collection
# Out:
# 100%|███████████████████████████████████████| 1695/1695 [02:12<00:00, 12.75it/s]
#           id                                       name  gallery_id
# 0         10                       Star Wars Collection       45434
# 17        84                   Indiana Jones Collection       45435
# 28       119           The Lord of the Rings Collection       45436
# 25       131                    Three Colors Collection       45437
# 37       151  Star Trek: The Original Series Collection       45438
# ...      ...                                        ...         ...
# 4382  479692                                     Robert       47124
# 241   479888                       The Thing Collection       47125
# 3849  479971                           Sağ Salim Serisi       47126
# 1996  480071               Maria, ihm schmeckt's nicht!       47127
# 4300  480160                 All of My Heart Collection       47128
#
# [1695 rows x 3 columns]

# %% [markdown]
# ## People

# %%
size = 0
gallery_last = gallery[-1]
for label, data  in tqdm(people.iterrows(), total=people.shape[0]):
    gallery.append(gallery_id)
    try:
        if size < MAX_FOLDER_IMAGE_GB * 1024**3:
            response = requests.get(f'{URL_API}person/{data["id"]}?api_key={API_KEY}')
            if response.status_code == 200:
                response = response.json()
                image, s = download_poster(MKDIR_PEOPLE, response['profile_path'])
                photos.append({
                    'url': image,
                    'gallery_id': gallery_id,
                    'order': 1,
                })
                size = size + s
            else:
                raise Exception()
        else:
            raise Exception()
    except Exception as e:
        photos.append({
            'url': '00000000-0000-0000-0000-000000000000',
            'gallery_id': gallery_id,
            'order': 1,
        })
    finally:
        gallery_id = gallery_id + 1
people['gallery_id'] = gallery[gallery_last:]
people
# Out:
# 100%|██████████████████████████████████| 353343/353343 [07:34<00:00, 777.04it/s]
#               id      name     surname  gender  gallery_id
# 161631         1    George       Lucas       2       47129
# 195489         2      Mark      Hamill       2       47130
# 340878         3  Harrison        Ford       2       47131
# 20669          4    Carrie      Fisher       1       47132
# 142927         5     Peter     Cushing       2       47133
# ...          ...       ...         ...     ...         ...
# 528206   1907923       Pia      Edlund       1      400467
# 528207   1907926     Stina  Elinderson       0      400468
# 922497   1907940      Mark     Devries       0      400469
# 1001848  1908001       Joe      Barton       2      400470
# 546614   1908262     Morse       Diggs       0      400471
#
# [353343 rows x 5 columns]

# %%
photos = pd.DataFrame(photos)
photos.head()
# Out:
#                                     url  gallery_id  order
# 0  a19c1a68-e9b5-4af0-9b7b-175ab593501f           1      1
# 1  00000000-0000-0000-0000-000000000000           1      2
# 2  b49c5b5b-c969-4b86-b06c-6ee8a71b385f           2      1
# 3  00000000-0000-0000-0000-000000000000           2      2
# 4  c7df5eaa-476e-44be-aa45-e6b6eb9b68bd           3      1

# %%
gallery_table = pd.DataFrame({
    'id': gallery,
})
gallery_table.head()
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %% [markdown]
# # Ustawienie wartości domyślnych

# %% [markdown]
# ## Movies

# %%
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if data['budget'] == 0:
        movies.at[label, 'budget'] = None        
    if data['homepage'] == '':
        movies.at[label, 'homepage'] = None
    if data['title'] == data['original_title']:
        movies.at[label, 'original_title'] = ''        
    if data['original_language_id'] == '':
        movies.at[label, 'original_language_id'] = None
    if data['release_date'] == '':
        movies.at[label, 'release_date'] = None
    if data['revenue'] == '':
        movies.at[label, 'revenue'] = None
    if data['runtime'] == '':
        movies.at[label, 'runtime'] = None
    if data['status_id'] == '':
        movies.at[label, 'status_id'] = 'Unknown'
movies['visibility'] = True
movies.head()
# Out:
# 100%|███████████████████████████████████| 45433/45433 [00:09<00:00, 4669.28it/s]
#        adult collection_id      budget  \
# 4342   False          None         NaN
# 12947  False          None         NaN
# 17     False          None   4000000.0
# 474    False          None         NaN
# 256    False            10  11000000.0
#
#                                                 homepage  id  \
# 4342                                                None   2
# 12947                                               None   3
# 17                                                  None   5
# 474                                                 None   6
# 256    http://www.starwars.com/films/star-wars-episod...  11
#
#       original_language_id        original_title  \
# 4342                    fi
# 12947                   fi  Varjoja paratiisissa
# 17                      en
# 474                     en
# 256                     en
#
#                                                 overview release_date  \
# 4342   Taisto Kasurinen is a Finnish coal miner whose...   1988-10-21
# 12947  An episode in the life of Nikander, a garbage ...   1986-10-16
# 17     It's Ted the Bellhop's first night on the job....   1995-12-09
# 474    While racing to a boxing match, Frank, Mike, J...   1993-10-15
# 256    Princess Leia is captured and held hostage by ...   1977-05-25
#
#          revenue runtime status_id  \
# 4342           0    69.0  Released
# 12947          0    76.0  Released
# 17       4300000    98.0  Released
# 474     12136938   110.0  Released
# 256    775398007   121.0  Released
#
#                                                  tagline                title  \
# 4342                                                                    Ariel
# 12947                                                     Shadows in Paradise
# 17     Twelve outrageous guests. Four scandalous requ...           Four Rooms
# 474       Don't move. Don't whisper. Don't even breathe.       Judgment Night
# 256         A long time ago in a galaxy far, far away...            Star Wars
#
#        video  gallery_id  visibility
# 4342   False           1        True
# 12947  False           2        True
# 17     False           3        True
# 474    False           4        True
# 256    False           5        True

# %% [markdown]
# ## Przeliczenie średniej ocen

# %%
movies = movies.merge(
    ratings[ratings.movie_id.isin(movies.id.unique()[movies.status_id == 'Released'])].groupby(['movie_id']).agg(
        average_vote=pd.NamedAgg(column='rating', aggfunc=np.mean),
        count_vote=pd.NamedAgg(column='rating', aggfunc='count'),
    ), left_on='id', right_on='movie_id', how='left'
)

# %%
movies[~movies.id.isin(ratings.groupby(['movie_id']).agg(
    average_vote=pd.NamedAgg(column='rating', aggfunc=np.mean),
    count_vote=pd.NamedAgg(column='rating', aggfunc='count'),).index.tolist())
]
# Out:
#        adult collection_id  budget  \
# 620    False          None     NaN
# 1166   False          None     NaN
# 1879   False        177062     NaN
# 2026   False          None     NaN
# 2081   False          None     NaN
# ...      ...           ...     ...
# 45117  False          None     NaN
# 45125  False          None     NaN
# 45126  False          None     NaN
# 45129  False          None     NaN
# 45413  False          None     NaN
#
#                                                 homepage      id  \
# 620                                                 None     798
# 1166                                                None    1848
# 1879                                                None    3941
# 2026                                                None    4529
# 2081                                                None    4709
# ...                                                  ...     ...
# 45117                                               None  429392
# 45125                                               None  429788
# 45126  http://www.sho.com/titles/3437477/tony-roberts...  429792
# 45129                                               None  429803
# 45413                                               None  461257
#
#       original_language_id       original_title  \
# 620                     de
# 1166                    en
# 1879                    en
# 2026                    en
# 2081                    fr  La Fête à Henriette
# ...                    ...                  ...
# 45117                   en
# 45125                   en
# 45126                   en
# 45129                   en
# 45413                   en
#
#                                                 overview release_date  \
# 620    Pünktchen und Anton is a 1953 German film base...   1953-08-26
# 1166   Private eye Philip Marlowe and his bride move ...   1998-07-25
# 1879   The 8th film in the Blondie series  - Blondie ...   1941-02-27
# 2026   Professor Bower, an American physicist, is eff...   1966-10-20
# 2081   Two scriptwriters argue about the fate of Henr...   1952-12-17
# ...                                                  ...          ...
# 45117  Ian Harvie is not quite the kind of man you mi...   2016-12-29
# 45125  Armed with his ferociously aggressive style of...   2016-11-24
# 45126  Detroit native Tony T. Roberts returns to his ...   2016-12-02
# 45129  The Live Series is an exclusive comedy special...   2015-02-17
# 45413  50 years after decriminalisation of homosexual...   2017-06-09
#
#        revenue runtime status_id  \
# 620          0    91.0  Released
# 1166         0    92.0  Released
# 1879         0    72.0  Released
# 2026         0   106.0  Released
# 2081         0   118.0  Released
# ...        ...     ...       ...
# 45117        0    58.0  Released
# 45125        0    59.0  Released
# 45126        0    50.0  Released
# 45129        0     0.0  Released
# 45413        0    75.0  Released
#
#                                                  tagline  \
# 620
# 1166     Sex. Murder. Marlowe. This town has everything.
# 1879   Where there's a Bumstead...there's always trou...
# 2026
# 2081
# ...                                                  ...
# 45117
# 45125
# 45126
# 45129
# 45413
#
#                                     title  video  gallery_id  visibility  \
# 620                   Pünktchen und Anton  False         621        True
# 1166                       Poodle Springs  False        1167        True
# 1879                   Blondie Goes Latin  False        1880        True
# 2026                         The Defector  False        2027        True
# 2081                Holiday for Henrietta  False        2082        True
# ...                                   ...    ...         ...         ...
# 45117   Ian Harvie: May the Best Cock Win  False       45118        True
# 45125      Aries Spears: Comedy Blueprint  False       45126        True
# 45126  Tony Roberts: Motorcity Motormouth  False       45127        True
# 45129       Barry Hilton: The Live Series  False       45130        True
# 45413                            Queerama  False       45414        True
#
#        average_vote  count_vote
# 620             NaN         NaN
# 1166            NaN         NaN
# 1879            NaN         NaN
# 2026            NaN         NaN
# 2081            NaN         NaN
# ...             ...         ...
# 45117           NaN         NaN
# 45125           NaN         NaN
# 45126           NaN         NaN
# 45129           NaN         NaN
# 45413           NaN         NaN
#
# [722 rows x 19 columns]

# %%
movies
# Out:
#        adult collection_id      budget  \
# 0      False          None         NaN
# 1      False          None         NaN
# 2      False          None   4000000.0
# 3      False          None         NaN
# 4      False            10  11000000.0
# ...      ...           ...         ...
# 45428  False          None         NaN
# 45429  False          None         NaN
# 45430  False          None         NaN
# 45431  False          None   1254040.0
# 45432  False          None         NaN
#
#                                                 homepage      id  \
# 0                                                   None       2
# 1                                                   None       3
# 2                                                   None       5
# 3                                                   None       6
# 4      http://www.starwars.com/films/star-wars-episod...      11
# ...                                                  ...     ...
# 45428                                               None  465044
# 45429                                               None  467731
# 45430                                               None  468343
# 45431                                    http://lmtr.fi/  468707
# 45432                                               None  469172
#
#       original_language_id                    original_title  \
# 0                       fi
# 1                       fi              Varjoja paratiisissa
# 2                       en
# 3                       en
# 4                       en
# ...                    ...                               ...
# 45428                   en
# 45429                   en
# 45430                   fi
# 45431                   fi  Lauri Mäntyvaaran tuuheet ripset
# 45432                   pt  Manoel dans l'île des merveilles
#
#                                                 overview release_date  \
# 0      Taisto Kasurinen is a Finnish coal miner whose...   1988-10-21
# 1      An episode in the life of Nikander, a garbage ...   1986-10-16
# 2      It's Ted the Bellhop's first night on the job....   1995-12-09
# 3      While racing to a boxing match, Frank, Mike, J...   1993-10-15
# 4      Princess Leia is captured and held hostage by ...   1977-05-25
# ...                                                  ...          ...
# 45428  A horror comedy spoofing conspiracy theory mov...   2017-06-28
# 45429  Fifteen-year-old girl Dotty Fisher is assaulte...   1956-02-19
# 45430  In the 1910s, beautiful young Silja loses both...   1956-01-01
# 45431                                                      2017-07-28
# 45432  Manuel is a young boy who travels from long ag...   1984-08-02
#
#          revenue runtime status_id  \
# 0              0    69.0  Released
# 1              0    76.0  Released
# 2        4300000    98.0  Released
# 3       12136938   110.0  Released
# 4      775398007   121.0  Released
# ...          ...     ...       ...
# 45428          0    90.0  Released
# 45429          0    60.0  Released
# 45430          0    87.0  Released
# 45431          0    90.0  Released
# 45432          0   130.0  Released
#
#                                                  tagline  \
# 0
# 1
# 2      Twelve outrageous guests. Four scandalous requ...
# 3         Don't move. Don't whisper. Don't even breathe.
# 4           A long time ago in a galaxy far, far away...
# ...                                                  ...
# 45428                                 Horrifically Funny
# 45429
# 45430
# 45431
# 45432
#
#                                   title  video  gallery_id  visibility  \
# 0                                 Ariel  False           1        True
# 1                   Shadows in Paradise  False           2        True
# 2                            Four Rooms  False           3        True
# 3                        Judgment Night  False           4        True
# 4                             Star Wars  False           5        True
# ...                                 ...    ...         ...         ...
# 45428                         Abduction  False       45429        True
# 45429       Tragedy in a Temporary Town  False       45430        True
# 45430          Silja - nuorena nukkunut  False       45431        True
# 45431  Thick Lashes of Lauri Mäntyvaara  False       45432        True
# 45432   Manuel on the Island of Wonders  False       45433        True
#
#        average_vote  count_vote
# 0          7.347328       262.0
# 1          7.540230        87.0
# 2          6.818062      6090.0
# 3          5.849725      1271.0
# 4          8.264599     77045.0
# ...             ...         ...
# 45428      1.000000         1.0
# 45429      7.000000         1.0
# 45430      6.500000         4.0
# 45431      8.000000         1.0
# 45432      7.666667         3.0
#
# [45433 rows x 19 columns]

# %% [markdown]
# ## Rozdzielenie Movies

# %%
status = []
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if not data['status_id'] in status:
        status.append(data['status_id'])
    movies.at[label, 'status_id'] = status.index(data['status_id']) + 1
movies.head()
# Out:
# 100%|███████████████████████████████████| 45433/45433 [00:05<00:00, 7944.08it/s]
#    adult collection_id      budget  \
# 0  False          None         NaN
# 1  False          None         NaN
# 2  False          None   4000000.0
# 3  False          None         NaN
# 4  False            10  11000000.0
#
#                                             homepage  id original_language_id  \
# 0                                               None   2                   fi
# 1                                               None   3                   fi
# 2                                               None   5                   en
# 3                                               None   6                   en
# 4  http://www.starwars.com/films/star-wars-episod...  11                   en
#
#          original_title                                           overview  \
# 0                        Taisto Kasurinen is a Finnish coal miner whose...
# 1  Varjoja paratiisissa  An episode in the life of Nikander, a garbage ...
# 2                        It's Ted the Bellhop's first night on the job....
# 3                        While racing to a boxing match, Frank, Mike, J...
# 4                        Princess Leia is captured and held hostage by ...
#
#   release_date    revenue runtime status_id  \
# 0   1988-10-21          0    69.0         1
# 1   1986-10-16          0    76.0         1
# 2   1995-12-09    4300000    98.0         1
# 3   1993-10-15   12136938   110.0         1
# 4   1977-05-25  775398007   121.0         1
#
#                                              tagline                title  \
# 0                                                                   Ariel
# 1                                                     Shadows in Paradise
# 2  Twelve outrageous guests. Four scandalous requ...           Four Rooms
# 3     Don't move. Don't whisper. Don't even breathe.       Judgment Night
# 4       A long time ago in a galaxy far, far away...            Star Wars
#
#    video  gallery_id  visibility  average_vote  count_vote
# 0  False           1        True      7.347328       262.0
# 1  False           2        True      7.540230        87.0
# 2  False           3        True      6.818062      6090.0
# 3  False           4        True      5.849725      1271.0
# 4  False           5        True      8.264599     77045.0

# %%
status = pd.DataFrame({
    'id': range(1, len(status) + 1),
    'name':status,
})
status.head()
# Out:
#    id           name
# 0   1       Released
# 1   2  In Production
# 2   3        Rumored
# 3   4        Planned
# 4   5        Unknown

# %% [markdown]
# ### Zamiana kolejności statusów

# %%
new_order = {
    1: 2, 
    2: 1
}
for label, data  in tqdm(movies.iterrows(), total=movies.shape[0]):
    if data['status_id'] in new_order.keys():
        movies.at[label, 'status_id'] = new_order[data['status_id']]
movies.head()
# Out:
# 100%|███████████████████████████████████| 45433/45433 [00:05<00:00, 8882.93it/s]
#    adult collection_id      budget  \
# 0  False          None         NaN
# 1  False          None         NaN
# 2  False          None   4000000.0
# 3  False          None         NaN
# 4  False            10  11000000.0
#
#                                             homepage  id original_language_id  \
# 0                                               None   2                   fi
# 1                                               None   3                   fi
# 2                                               None   5                   en
# 3                                               None   6                   en
# 4  http://www.starwars.com/films/star-wars-episod...  11                   en
#
#          original_title                                           overview  \
# 0                        Taisto Kasurinen is a Finnish coal miner whose...
# 1  Varjoja paratiisissa  An episode in the life of Nikander, a garbage ...
# 2                        It's Ted the Bellhop's first night on the job....
# 3                        While racing to a boxing match, Frank, Mike, J...
# 4                        Princess Leia is captured and held hostage by ...
#
#   release_date    revenue runtime status_id  \
# 0   1988-10-21          0    69.0         2
# 1   1986-10-16          0    76.0         2
# 2   1995-12-09    4300000    98.0         2
# 3   1993-10-15   12136938   110.0         2
# 4   1977-05-25  775398007   121.0         2
#
#                                              tagline                title  \
# 0                                                                   Ariel
# 1                                                     Shadows in Paradise
# 2  Twelve outrageous guests. Four scandalous requ...           Four Rooms
# 3     Don't move. Don't whisper. Don't even breathe.       Judgment Night
# 4       A long time ago in a galaxy far, far away...            Star Wars
#
#    video  gallery_id  visibility  average_vote  count_vote
# 0  False           1        True      7.347328       262.0
# 1  False           2        True      7.540230        87.0
# 2  False           3        True      6.818062      6090.0
# 3  False           4        True      5.849725      1271.0
# 4  False           5        True      8.264599     77045.0

# %%
for label, data  in tqdm(status.iterrows(), total=status.shape[0]):
    if data['id'] in new_order.keys():
        status.at[label, 'id'] = new_order[data['id']]
status.sort_values('id').head()
# Out:
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 353.02it/s]
#    id           name
# 1   1  In Production
# 0   2       Released
# 2   3        Rumored
# 3   4        Planned
# 4   5        Unknown

# %% [markdown]
# ## Zmiana statusu

# %%
movies.loc[(movies['id'] == 48259) | (movies['id'] == 44265), 'status_id'] = 2

# %%
movies[((movies.status_id == 4) | (movies.status_id == 1) | (movies.status_id == 6)) & (movies.release_date.notnull())].sort_values('release_date')
# Out:
#        adult collection_id      budget                          homepage  \
# 10790  False          None         NaN                              None
# 21653  False        102940         NaN             http://breakblade.jp/
# 22965  False        101646         NaN                              None
# 21118  False          None         NaN  http://thelastmountainmovie.com/
# 22108  False          None         NaN    http://www.magictripmovie.com/
# ...      ...           ...         ...                               ...
# 44762  False          None         NaN                              None
# 42108  False          None         NaN                              None
# 15842  False         14890         NaN                              None
# 40973  False          None  12000000.0                              None
# 25861  False         87096         NaN       http://www.avatarmovie.com/
#
#            id original_language_id                    original_title  \
# 10790   25073                   en
# 21653   55438                   en  Break Blade 6: Doukoku no Toride
# 22965   61123                   fi           Vares – Huhtikuun tytöt
# 21118   53328                   en
# 22108   57211                   en
# ...       ...                  ...                               ...
# 44762  412059                   en
# 42108  332283                   en
# 15842   38700                   en
# 40973  299782                   en
# 25861   76600                   en
#
#                                                 overview release_date  \
# 10790  A screenwriter who travels to an abandoned hou...   2009-01-01
# 21653  Baldr and his men carries Delphine back to the...   2011-03-25
# 22965  Tough Finnish detective Jussi Vares gets hired...   2011-04-20
# 21118  In the valleys of Appalachia, a battle is bein...   2011-06-03
# 22108  A freewheeling portrait of Ken Kesey and the M...   2011-08-05
# ...                                                  ...          ...
# 44762  In forgotten towns along the American border, ...   2018-04-04
# 42108  The love affair between poet Percy Shelley and...   2018-04-25
# 15842  The continuing adventures of Miami detectives ...   2018-11-07
# 40973  Orson Welles' unfinished masterpiece, restored...   2018-12-31
# 25861                         A sequel to Avatar (2009).   2020-12-16
#
#        revenue runtime status_id                              tagline  \
# 10790        0    89.0         1
# 21653        0    50.0         6
# 22965        0    95.0         1
# 21118    90425    95.0         6               A Fight For Our Future
# 22108        0   107.0         6  A drug-fuelled road trip in the 60s
# ...        ...     ...       ...                                  ...
# 44762        0   105.0         6
# 42108        0     0.0         6
# 15842        0     0.0         4
# 40973        0     0.0         6
# 25861        0     0.0         1
#
#                                                   title  video  gallery_id  \
# 10790                                          Deadline  False       10791
# 21653  Broken Blade: Book Six - Enclave of Lamentations  False       21654
# 22965                        Vares - The Girls of April  False       22966
# 21118                                 The Last Mountain  False       21119
# 22108                                        Magic Trip  False       22109
# ...                                                 ...    ...         ...
# 44762                                      Mobile Homes  False       44763
# 42108                                      Mary Shelley  False       42109
# 15842                                 Bad Boys for Life  False       15843
# 40973                        The Other Side of the Wind  False       40974
# 25861                                          Avatar 2  False       25862
#
#        visibility  average_vote  count_vote
# 10790        True           NaN         NaN
# 21653        True           NaN         NaN
# 22965        True           NaN         NaN
# 21118        True           NaN         NaN
# 22108        True           NaN         NaN
# ...           ...           ...         ...
# 44762        True           NaN         NaN
# 42108        True           NaN         NaN
# 15842        True           NaN         NaN
# 40973        True           NaN         NaN
# 25861        True           NaN         NaN
#
# [127 rows x 19 columns]

# %% [markdown]
# # Oczyszczenie danych

# %% [markdown]
# ## Movies

# %%
movies['homepage'] = movies.homepage.str.strip()
movies['original_title'] = movies.original_title.str.strip()
movies['overview'] = movies.overview.str.strip()
movies['tagline'] = movies.tagline.str.strip()
movies['title'] = movies.title.str.strip()

movies.head()
# Out:
#    adult collection_id      budget  \
# 0  False          None         NaN
# 1  False          None         NaN
# 2  False          None   4000000.0
# 3  False          None         NaN
# 4  False            10  11000000.0
#
#                                             homepage  id original_language_id  \
# 0                                               None   2                   fi
# 1                                               None   3                   fi
# 2                                               None   5                   en
# 3                                               None   6                   en
# 4  http://www.starwars.com/films/star-wars-episod...  11                   en
#
#          original_title                                           overview  \
# 0                        Taisto Kasurinen is a Finnish coal miner whose...
# 1  Varjoja paratiisissa  An episode in the life of Nikander, a garbage ...
# 2                        It's Ted the Bellhop's first night on the job....
# 3                        While racing to a boxing match, Frank, Mike, J...
# 4                        Princess Leia is captured and held hostage by ...
#
#   release_date    revenue runtime status_id  \
# 0   1988-10-21          0    69.0         2
# 1   1986-10-16          0    76.0         2
# 2   1995-12-09    4300000    98.0         2
# 3   1993-10-15   12136938   110.0         2
# 4   1977-05-25  775398007   121.0         2
#
#                                              tagline                title  \
# 0                                                                   Ariel
# 1                                                     Shadows in Paradise
# 2  Twelve outrageous guests. Four scandalous requ...           Four Rooms
# 3     Don't move. Don't whisper. Don't even breathe.       Judgment Night
# 4       A long time ago in a galaxy far, far away...            Star Wars
#
#    video  gallery_id  visibility  average_vote  count_vote
# 0  False           1        True      7.347328       262.0
# 1  False           2        True      7.540230        87.0
# 2  False           3        True      6.818062      6090.0
# 3  False           4        True      5.849725      1271.0
# 4  False           5        True      8.264599     77045.0

# %% [markdown]
# ## Collections

# %%
collection['name'] = collection.name.str.strip()
collection.head()
# Out:
#      id                                       name  gallery_id
# 0    10                       Star Wars Collection       45434
# 17   84                   Indiana Jones Collection       45435
# 28  119           The Lord of the Rings Collection       45436
# 25  131                    Three Colors Collection       45437
# 37  151  Star Trek: The Original Series Collection       45438

# %% [markdown]
# ## Genres

# %%
genres['name'] = genres.name.str.strip()
genres.head()
# Out:
#        id       name
# 6784   12  Adventure
# 65263  14    Fantasy
# 37860  16  Animation
# 29936  18      Drama
# 19538  27     Horror

# %% [markdown]
# ## Countries

# %%
countries['name'] = countries.name.str.strip()
countries.head()
# Out:
#       iso_3166_1                  name
# 36535         AE  United Arab Emirates
# 43061         AF           Afghanistan
# 45308         AL               Albania
# 40191         AM               Armenia
# 38993         AN  Netherlands Antilles

# %% [markdown]
# ## Languages

# %%
languages['name'] = languages.name.str.strip()
languages.head()
# Out:
#       iso_639_1       name
# 47548        ab
# 1274         af  Afrikaans
# 36875        am
# 8625         ar    العربية
# 10013        as

# %% [markdown]
# ## Cast

# %%
cast['character'] = cast.character.str.strip()
cast = cast[cast.character != '']
cast.head()
# Out:
#    movie_id                character  person_id  order
# 0       862            Woody (voice)         31      0
# 1       862   Buzz Lightyear (voice)      12898      1
# 2       862  Mr. Potato Head (voice)       7167      2
# 3       862       Slinky Dog (voice)      12899      3
# 4       862              Rex (voice)      12900      4

# %% [markdown]
# ## Crew

# %%
crew['department'] = crew.department.str.strip()
crew['job'] = crew.job.str.strip()

crew.head()
# Out:
#    movie_id department         job  person_id
# 0       862  Directing    Director       7879
# 1       862    Writing  Screenplay      12891
# 2       862    Writing  Screenplay          7
# 3       862    Writing  Screenplay      12892
# 4       862    Writing  Screenplay      12893

# %% [markdown]
# ## People

# %%
people['name'] = people.name.str.strip()
people['surname'] = people.surname.str.strip()

people.head()
# Out:
#         id      name  surname  gender  gallery_id
# 161631   1    George    Lucas       2       47129
# 195489   2      Mark   Hamill       2       47130
# 340878   3  Harrison     Ford       2       47131
# 20669    4    Carrie   Fisher       1       47132
# 142927   5     Peter  Cushing       2       47133

# %% [markdown]
# # Zapisanie danych do bazy danych
#
# ## Przygotowanie połączenia

# %%
engine = create_engine(f'mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}/{DB_NAME}')

# %% [markdown]
# ### Zapisanie tabel

# %%
list_tabels = [
    { 'nazwa_tabeli': 'photos_gallery', 'data': gallery_table, },
    { 'nazwa_tabeli': 'photos_photo', 'data': photos, },
    { 'nazwa_tabeli': 'movies_collection', 'data': collection, },
    { 'nazwa_tabeli': 'movies_movie_status', 'data': status, },
    { 'nazwa_tabeli': 'movies_language', 'data': languages, },
    { 'nazwa_tabeli': 'movies_country', 'data': countries, },
    { 'nazwa_tabeli': 'movies_company', 'data': company, },
    { 'nazwa_tabeli': 'movies_keyword', 'data': keywords, },
    { 'nazwa_tabeli': 'movies_genre', 'data': genres, },
    { 'nazwa_tabeli': 'movies_movie', 'data': movies, },
    { 'nazwa_tabeli': 'movies_movie_genres', 'data': movies_genres, },
    { 'nazwa_tabeli': 'movies_movie_keywords', 'data': movies_keywords, },
    { 'nazwa_tabeli': 'movies_movie_production_companies', 'data': movies_companies, },
    { 'nazwa_tabeli': 'movies_movie_production_countries', 'data': movies_countries, },
    { 'nazwa_tabeli': 'movies_movie_spoken_languages', 'data': spoken_languages, },
    { 'nazwa_tabeli': 'movies_person', 'data': people, },
    { 'nazwa_tabeli': 'movies_crew', 'data': crew, },
    { 'nazwa_tabeli': 'movies_cast', 'data': cast, },
]

for x in tqdm(list_tabels):
    x['data'].to_sql(f'{x["nazwa_tabeli"]}', con=engine, if_exists='append', index=False, method='multi', chunksize=1000)
# Out:
# 100%|███████████████████████████████████████████| 18/18 [08:54<00:00, 29.71s/it]
